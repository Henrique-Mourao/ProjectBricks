# %%
from pyspark.sql import SparkSession


df_spark = spark.read.csv("minha-biblioteca-2024.csv", header=True, inferSchema=True)

# %%
resultado = spark.sql("select * from biblioteca")
resultado.columns
